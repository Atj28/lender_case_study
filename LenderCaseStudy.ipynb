# %%
"""
Data Understanding
Once you have the dataset:
Overview of the data (using head(), info(), describe() in Pandas).
The structure and types of variables (categorical, numerical).
Check for missing values and duplicates.
"""
# Out:
# '\nData Understanding\nOnce you have the dataset:\nOverview of the data (using head(), info(), describe() in Pandas).\nThe structure and types of variables (categorical, numerical).\nCheck for missing values and duplicates.\n'

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('loan.csv')
data.head()
# Out:
# /var/folders/kc/tzhtr9pj0k7bh_cbzv1qw2180000gp/T/ipykernel_23676/3241341964.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('loan.csv')
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# ...

# %%
data = pd.read_csv('loan.csv',low_memory=False )
data.head(5)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
data.shape
# Out:
# (39717, 111)

# %%
data.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
"""
 Data Cleaning
Before performing EDA, clean the data:

Handle Missing Values: Decide how to deal with missing values (e.g., imputation, removal).
Remove Duplicates: Check and remove duplicate entries if necessary.
Convert Data Types: Ensure categorical variables are appropriately encoded.
"""
# Out:
# '\n Data Cleaning\nBefore performing EDA, clean the data:\n\nHandle Missing Values: Decide how to deal with missing values (e.g., imputation, removal).\nRemove Duplicates: Check and remove duplicate entries if necessary.\nConvert Data Types: Ensure categorical variables are appropriately encoded.\n'

# %%
data.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
# Get the columns with exactly 39678 missing values
cols_to_drop = data.columns[data.isnull().sum() == 39717]

# Drop these columns from the DataFrame
data2 = data.drop(columns=cols_to_drop)

# %%
data2.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# grade                             0
# sub_grade                         0
# emp_title                      2459
# emp_length                     1075
# home_ownership                    0
# annual_inc                        0
# verification_status               0
# issue_d                           0
# loan_status                       0
# pymnt_plan                        0
# url                               0
# desc                          12942
# purpose                           0
# title                            11
# zip_code                          0
# addr_state                        0
# dti                               0
# delinq_2yrs                       0
# ...

# %%
data2['emp_title'] = data2['title'].fillna('Others')

# %%
data2['emp_title'] = data2['emp_title'].fillna('Others')

# %%
data2['emp_length'] = data2['emp_length'].fillna('NA')

# %%
# Convert the 'revol_util' column to string type, forcing any non-string values to NaN
data2['revol_util'] = data2['revol_util'].astype(str)

# Remove '%' from the revol_util column and convert to float
data2['revol_util'] = data2['revol_util'].str.replace('%', '', regex=False)

# Convert to float, coercing errors (like empty strings) to NaN
data2['revol_util'] = pd.to_numeric(data2['revol_util'], errors='coerce')

# Calculate the mean of the revol_util column, ignoring NaN values
mean_revol_util = data2['revol_util'].mean()

# Replace NaN values in the revol_util column with the mean value
data2['revol_util'] = data2['revol_util'].fillna(mean_revol_util)

# %%
data2['last_pymnt_d'] = data2['last_pymnt_d'].fillna('NA')
data2['collections_12_mths_ex_med'] = data2['collections_12_mths_ex_med'].fillna('NA')
data2['last_credit_pull_d'] = data2['last_credit_pull_d'].fillna('NA')
data2['chargeoff_within_12_mths'] = data2['chargeoff_within_12_mths'].fillna('NA')
data2['pub_rec_bankruptcies'] = data2['pub_rec_bankruptcies'].fillna('NA')
data2['tax_liens'] = data2['tax_liens'].fillna('NA')

# %%
# Get the columns with exactly 39678 missing values
cols_to_drop = data.columns[data.isnull().sum() >= 1]

# Drop these columns from the DataFrame
data2 = data.drop(columns=cols_to_drop)

# %%
data2.isnull().sum()
# Out:
# id                         0
# member_id                  0
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# term                       0
# int_rate                   0
# installment                0
# grade                      0
# sub_grade                  0
# home_ownership             0
# annual_inc                 0
# verification_status        0
# issue_d                    0
# loan_status                0
# pymnt_plan                 0
# url                        0
# purpose                    0
# zip_code                   0
# addr_state                 0
# dti                        0
# delinq_2yrs                0
# earliest_cr_line           0
# inq_last_6mths             0
# open_acc                   0
# pub_rec                    0
# revol_bal                  0
# total_acc                  0
# initial_list_status        0
# out_prncp                  0
# out_prncp_inv              0
# total_pymnt                0
# ...

# %%
data2.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
data2.shape
# Out:
# (39717, 43)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       39717 non-null  int64
#  1   member_id                39717 non-null  int64
#  2   loan_amnt                39717 non-null  int64
#  3   funded_amnt              39717 non-null  int64
#  4   funded_amnt_inv          39717 non-null  float64
#  5   term                     39717 non-null  object
#  6   int_rate                 39717 non-null  object
#  7   installment              39717 non-null  float64
#  8   grade                    39717 non-null  object
#  9   sub_grade                39717 non-null  object
#  10  home_ownership           39717 non-null  object
#  11  annual_inc               39717 non-null  float64
#  12  verification_status      39717 non-null  object
#  13  issue_d                  39717 non-null  object
# ...

# %%
"""
 Univariate Analysis
Perform univariate analysis on both categorical and numerical columns.
This helps you understand the distribution of individual variables.

Categorical Variables:
For categorical variables like term, home_ownership, grade, sub_grade, loan_status, etc., 
visualize the count or proportion of each category.
"""
# Out:
# '\n Univariate Analysis\nPerform univariate analysis on both categorical and numerical columns.\nThis helps you understand the distribution of individual variables.\n\nCategorical Variables:\nFor categorical variables like term, home_ownership, grade, sub_grade, loan_status, etc., \nvisualize the count or proportion of each category.\n'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Univariate analysis of loan status
plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='loan_status')
plt.title('Distribution of Loan Status')
plt.show()

# %%
# Histogram for loan amount
plt.figure(figsize=(8, 5))
sns.histplot(data['loan_amnt'], bins=20, kde=True)
plt.title('Loan Amount Distribution')
plt.show()

# %%
sns.countplot(data=data, x='verification_status')
plt.title('Income Verification Status')
plt.show()

# %%
verification_status_counts = data['verification_status'].value_counts()
# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(verification_status_counts, labels=verification_status_counts.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#99ff99','#ff9999'])
plt.title('Verification Status Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
sns.countplot(data=data, x='home_ownership')
plt.title('Home Ownership Status Distribution')
plt.show()

# %%
# Convert int_rate to numeric by stripping the '%' sign
data['int_rate'] = data['int_rate'].str.replace('%', '').astype(float)

plt.figure(figsize=(10, 6))
sns.histplot(data['int_rate'], bins=20, kde=True)
plt.title('Interest Rate Distribution')
plt.show()

# %%
"""
Segmented Univariate Analysis
Segment the univariate analysis by loan_status (or charged_off if you're using a binary target). 
For instance, visualize how loan_amnt, term, grade, and annual_inc differ for defaulted vs. fully paid loans.
"""
# Segment loan amount by loan status
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='loan_status', y='loan_amnt')
plt.title('Loan Amount vs Loan Status')
plt.show()

# %%
# Segment the loan_amnt based on grade
# Set up the figure size
plt.figure(figsize=(10, 6))

# Create a boxplot to show loan amounts by grade
sns.boxplot(x='grade', y='loan_amnt', data=data)

# Set plot labels and title
plt.title('Boxplot of Loan Amounts by Grade')
plt.xlabel('Grade')
plt.ylabel('Loan Amount')

plt.show()

# %%
"""
Bivariate Analysis
Examine relationships between two variables, 
particularly focusing on how they impact loan status. 
For example, analyze how loan_amnt, int_rate, and grade interact with loan_status.
"""
# Out:
# '\nBivariate Analysis\nExamine relationships between two variables, \nparticularly focusing on how they impact loan status. \nFor example, analyze how loan_amnt, int_rate, and grade interact with loan_status.\n'

# %%
sns.countplot(data=data, x='home_ownership', hue='loan_status')
plt.title('Loan Status vs Home Ownership')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=data, x='loan_status', y='loan_amnt')
plt.title('Loan Amount vs Loan Status')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=data, x='loan_status', y='int_rate')
plt.title('Interest Rate vs Loan Status')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=data, x='loan_status', y='dti')
plt.title('Debt-to-Income Ratio vs Loan Status')
plt.show()

# %%
# Create a crosstab of 'verification_status' and 'loan_status'
crosstab_data = pd.crosstab(data['verification_status'], data['loan_status'])

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(crosstab_data, annot=True, cmap="Blues", fmt='g')

# Set plot labels and title
plt.title('Heatmap of Verification Status vs Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Verification Status')

plt.show()

# %%
# Define income ranges
def categorize_income(income):
    if income <= 300000:
        return 'Up to 3 Lakh'
    elif income <= 1000000:
        return '3 to 10 Lakh'
    else:
        return '10 Lakh and above'

# Create a new column for income ranges
data['income_range'] = data['annual_inc'].apply(categorize_income)

# %%
# Create a contingency table
income_loan_status = pd.crosstab(data['income_range'], data['loan_status'])

# Display the table
print(income_loan_status)
# Out:
# loan_status        Charged Off  Current  Fully Paid
# income_range
# 10 Lakh and above            1        0          13
# 3 to 10 Lakh                20        4         137
# Up to 3 Lakh              5606     1136       32800

# %%
import matplotlib.pyplot as plt

# Plotting the bar chart
income_loan_status.plot(kind='bar', stacked=True)
plt.title('Loan Status by Income Range')
plt.xlabel('Income Range')
plt.ylabel('Number of Loans')
plt.legend(title='Loan Status')
plt.xticks(rotation=0)
plt.show()

# %%
# Calculate percentage of each loan status within each income range
income_loan_status_percentage = income_loan_status.div(income_loan_status.sum(axis=1), axis=0) * 100

# Display the percentages
print(income_loan_status_percentage)
# Out:
# loan_status        Charged Off   Current  Fully Paid
# income_range
# 10 Lakh and above     7.142857  0.000000   92.857143
# 3 to 10 Lakh         12.422360  2.484472   85.093168
# Up to 3 Lakh         14.177330  2.872895   82.949775

# %%
sns.pairplot(data[['loan_amnt', 'int_rate', 'annual_inc', 'dti', 'loan_status']], hue='loan_status')
plt.show()
